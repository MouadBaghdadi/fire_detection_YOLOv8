# %%
# !nvidia-smi

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.5/615.5 kB 8.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo task= detect mode = train model = yolov8n data= /content/drive/MyDrive/data/data.yaml epochs= 20 imgsz= 640
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 257MB/s]
# Ultralytics YOLOv8.0.187 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
